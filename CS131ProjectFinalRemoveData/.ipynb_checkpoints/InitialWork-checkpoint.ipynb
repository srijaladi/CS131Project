# %%
import re

txt = "The rain in Spain"
x = re.search("(?=[A-Za-z]+\d[A-Za-z])", txt)
print(x)
# Out:
# None

# %%
li = ["I would like to declare computer science", "Can I use transfer credits for math", "How do I officially make my major computer science", "I would like to take 106B and 103 together", "How many credits do I take for computer science"]
li = [i.lower() for i in li]
print(li)
ct = ["declaration", "course inquiry", "declaration", "course inquiry", "course inquiry"]
sw = ["and", "can", "do", "for", "how", "i", "to", "would"]

des = "how many general science credits do I need for graduation"
des = des.lower()

s = set()
t1 = []
t2 = []

for i,x in enumerate(li):
    for w in x.split(" "):
        if not(w in sw):
            if ct[i] == "declaration":
                t1.append(w)
            else:
                t2.append(w)
            s.add(w)
        
print(len(t1), len(t2), len(s))
print(s)

V = len(s)
l1 = len(t1)
l2 = len(t2)

p1, p2 = 1, 1
for w in des.split(" "):
    if w in s:
        p1 *= ((t1.count(w) + 1)/(l1 + V))
        p2 *= ((t2.count(w) + 1)/(l2 + V))
    
r1 = p1 * 0.4
r2 = p2 * 0.6
print(r1, r2)
print(np.log(r1), np.log(r2))
# Out:
# ['i would like to declare computer science', 'can i use transfer credits for math', 'how do i officially make my major computer science', 'i would like to take 106b and 103 together', 'how many credits do i take for computer science']
# 10 14 17
# {'many', 'make', 'transfer', 'my', '103', 'declare', 'like', '106b', 'computer', 'credits', 'officially', 'major', 'together', 'take', 'math', 'use', 'science'}
# 6.096631611034902e-05 0.00024168372998556605
# -9.705189041219032 -8.327880587433429

# %%
text = "Going in I thought the movie would be the most boring feature film of 2023 but I’m happy to say that I was pleasantly surprised The actors were far from dull and I loved everything about the set design There is no way I’m only watching this exhilarating production once"
text = text.lower()
print(len(text.split(" ")))
pos = ["happy", "pleasantly", "surprised", "loved", "exhilarating"]
neg = ["boring", "dull"]

v1, v2, v3, v4 = 0, 0, 1, np.log(50)
for w in text.split(" "):
    if w in pos:
        v1 += 1
    if w in neg:
        v2 += 1
        
        
print(v1, v2, v3, v4)

x1, x2, x3, x4 = 1.2, -2.1, 0.8, -0.6
b = 0.2

y = (x1 * v1) + (x2 * v2) + (x3 * v3) + (x4 * v4) + b

print(y)

print(1/(1 + np.exp(-y)))
print(-np.log(0.75))
# Out:
# 50
# 5 2 1 3.912023005428146
# 0.452786196743112
# 0.6113014726171028
# 0.2876820724517809

# %%
li = ["today I played games on my computer after doing my science homework", "Computer science is fun because it can do very cool things", "When we went to the store today we tried to find a computer but they were out of stock",
     "Biology is a science So is Chemistry And Physics Lots of things can be a science", "I do not like science because it is too difficult and even though people say computer science is fun I disagree because it is so frustrating when I find bugs I cannot fix", "My mom wouldn’t let me play fun games on my computer because I had to do my science homework She is so strict",
     "According to all known laws of aviation there is no way a bee should be able to fly", "We hope you’re doing well and having fun with this class Even though computer science is hard we believe in you Good luck with the rest of this exam"
     ]
li = [i.lower() for i in li]
ss = [set(i.lower().split(" ")) for i in li]
ds = []

qq = "computer science is fun"

for i,x in enumerate(li):
    d = {}
    for j,w in enumerate(x.split(" ")):
        d[w] = d.get(w,[]) + [j]
    ds.append(d)


for i,s in enumerate(ss):
    bad = False
    for w in qq.split(" "):
        if not(w in s):
            bad = True
            break
    if not(bad):
        print(i + 1)
        

for i,d in enumerate(ds):
    w0 = qq.split(" ")[0]
    ws = qq.split(" ")
    if w0 not in d:
        continue
    got = False
    for i0 in d[w0]:
        need = i0 + 1
        bad = False
        for w in ws[1:]:
            if not(w in d) or not(need in d[w]):
                bad = True
                break
            need = need + 1
        if not(bad):
            got = True
            break
    if (got):
        print(i + 1, d)
    
print(li)
# Out:
# 2
# 5
# 6
# 8
# 2 {'computer': [0], 'science': [1], 'is': [2], 'fun': [3], 'because': [4], 'it': [5], 'can': [6], 'do': [7], 'very': [8], 'cool': [9], 'things': [10]}
# 5 {'i': [0, 19, 27, 30], 'do': [1], 'not': [2], 'like': [3], 'science': [4, 16], 'because': [5, 21], 'it': [6, 22], 'is': [7, 17, 23], 'too': [8], 'difficult': [9], 'and': [10], 'even': [11], 'though': [12], 'people': [13], 'say': [14], 'computer': [15], 'fun': [18], 'disagree': [20], 'so': [24], 'frustrating': [25], 'when': [26], 'find': [28], 'bugs': [29], 'cannot': [31], 'fix': [32]}
# ['today i played games on my computer after doing my science homework', 'computer science is fun because it can do very cool things', 'when we went to the store today we tried to find a computer but they were out of stock', 'biology is a science so is chemistry and physics lots of things can be a science', 'i do not like science because it is too difficult and even though people say computer science is fun i disagree because it is so frustrating when i find bugs i cannot fix', 'my mom wouldn’t let me play fun games on my computer because i had to do my science homework she is so strict', 'according to all known laws of aviation there is no way a bee should be able to fly', 'we hope you’re doing well and having fun with this class even though computer science is hard we believe in you good luck with the rest of this exam']

# %%
print(sum([0.235, 0.428, 0.007, 0.155, 0.084, 0.091]))
print(sum( [0.381, 0.714, 0.095, 0.052, 0.022]))
print(sum( [0.483, 0.086, 0.076, 0.123, 0.090, 0.512]))
print(sum( [0.227, 0.003, 0.009, 0.000, 0.761]))
print(sum( [0.001, 0.037, 0.004, 0.693, 0.079]))
print(sum( [0.010, 0.005, 0.164, 0.524, 0.297]))
print(sum( [0.026, 0.899, 0.035, 0.040]))

def sigmoid(x):
    return (1/(1 + np.exp(-x)))

def relu(x):
    return (x >= 0) * x
 
W1 = np.array([[-1, 0.5], [2, 1]])
b1 = np.array([[0.2], [-7]])
W2 = np.array([0.4, 0.9])
b2 = 0.6

x = np.array([[3], [2]])

z1 = np.matmul(W1, x) + b1
a1 = relu(z1)

z2 = np.matmul(W2, a1) + b2
print(sigmoid(z2))


print(sigmoid(1.5))
# Out:
# 1.0
# 1.264
# 1.3699999999999999
# 1.0
# 0.814
# 1.0
# 1.0
# [0.81757448]
# 0.8175744761936437

# %%
import torch
import torchvision
import cifar10
import torchvision.datasets as D
import numpy as np
import torch.nn as nn
import matplotlib
from matplotlib import pyplot as plt
import time
import Models
from Models import Conv2dBlock, CNNClassifier
import utils
from utils import load_data

np.random.seed(42)
torch.manual_seed(42)

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

X_TRAIN, X_TEST, Y_TRAIN, Y_TEST = load_data(DEVICE)

ITERATIONS = 10000
BATCH_SIZE = 64
PRINT_EVERY = 100
OUT_CLASSES = 10
        

layers = [Conv2dBlock([3,32,32]), Conv2dBlock([32,64,64]), Conv2dBlock([64,128,128]), 
          nn.Flatten(), nn.Linear(2048,128), nn.ReLU(), nn.Linear(128,OUT_CLASSES)]
        
MODEL = CNNClassifier(layers, 1e-3, nn.functional.cross_entropy).to(DEVICE)

print("DOING BASELINE MODEL TRAINING")
print()

losses = []
train_start = time.time()

for itr in range(ITERATIONS+1):
    idxs = np.random.randint(0,50000, size = (BATCH_SIZE,))
        
    X, Y = X_TRAIN[idxs], Y_TRAIN[idxs]
    
    loss = MODEL.backprop(X,Y)
    if itr%PRINT_EVERY == 0:
        print(itr,loss)
    losses.append(loss)

train_time = time.time() - train_start
        
plt.clf()
plt.plot(np.arange(len(losses)), np.array(losses))
plt.title("Cross Entropy Loss over Training (Baseline Model)")
plt.show()
plt.clf()

test_start = time.time()
loss = MODEL.compute_loss(X_TEST, Y_TEST)
acc = MODEL.compute_accuracy(X_TEST, Y_TEST)
test_time = time.time() - test_start

print("Testing Set Cross Entropy Loss (Baseline Model):", loss)
print("Testing Set Accuracy (Baseline Model):", acc)

loss = MODEL.compute_loss(X_TRAIN, Y_TRAIN)
acc = MODEL.compute_accuracy(X_TRAIN, Y_TRAIN)

print("Training Set Cross Entropy Loss (Baseline Model):", loss)
print("Training Set Accuracy (Baseline Model):", acc)

print("TRAINING TIME:", train_time, "seconds")
print("TEST TIME:",test_time, "seconds")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# DOING BASELINE MODEL TRAINING
#
# 0 2.2943389415740967
# 100 1.9927153587341309
# 200 1.5725548267364502
# 300 1.7248287200927734
# 400 1.450641393661499
# 500 1.660408854484558
# 600 1.4007322788238525
# 700 1.318026065826416
# 800 1.1432029008865356
# 900 1.4927810430526733
# 1000 1.1255476474761963
# 1100 1.166626214981079
# 1200 1.309675931930542
# 1300 1.1326342821121216
# 1400 1.1851266622543335
# 1500 1.131097435951233
# 1600 0.9448041319847107
# 1700 0.9662469029426575
# 1800 1.1431208848953247
# 1900 0.8689776062965393
# 2000 0.9107990264892578
# 2100 1.1936208009719849
# 2200 0.8444869518280029
# 2300 0.8775249123573303
# 2400 0.8503451347351074
# 2500 0.6863454580307007
# 2600 0.9301682710647583
# 2700 0.6476162075996399
# 2800 0.852841317653656
# 2900 0.727329432964325
# 3000 0.6264047026634216
# 3100 0.8870484828948975
# 3200 0.5628611445426941
# 3300 0.6710310578346252
# 3400 0.5623313784599304
# 3500 0.5270071029663086
# 3600 0.6932108998298645
# 3700 0.8259970545768738
# 3800 0.4955981373786926
# 3900 0.5862823128700256
# 4000 0.5986502170562744
# 4100 0.6429906487464905
# 4200 0.47083601355552673
# 4300 0.7434177398681641
# 4400 0.5221257209777832
# 4500 0.45084935426712036
# 4600 0.6764928698539734
# 4700 0.3568435311317444
# 4800 0.5285843014717102
# 4900 0.5000097751617432
# 5000 0.46526846289634705
# 5100 0.4325752556324005
# 5200 0.4165530800819397
# 5300 0.4763199985027313
# 5400 0.43174320459365845
# 5500 0.6706559658050537
# 5600 0.47362977266311646
# 5700 0.5548195838928223
# 5800 0.38600507378578186
# 5900 0.57467120885849
# 6000 0.4748961627483368
# 6100 0.4170362651348114
# 6200 0.34084996581077576
# 6300 0.5680556297302246
# 6400 0.6699369549751282
# 6500 0.4599376618862152
# 6600 0.4578598439693451
# 6700 0.2188703715801239
# 6800 0.4254978895187378
# 6900 0.32001087069511414
# 7000 0.32033416628837585
# 7100 0.48118990659713745
# 7200 0.22300031781196594
# 7300 0.2615055441856384
# 7400 0.49372756481170654
# 7500 0.37987399101257324
# 7600 0.27437910437583923
# 7700 0.44560885429382324
# 7800 0.3220597207546234
# 7900 0.2850625216960907
# 8000 0.4036336839199066
# 8100 0.48776906728744507
# 8200 0.32410937547683716
# 8300 0.24387358129024506
# 8400 0.3088770806789398
# 8500 0.16913504898548126
# 8600 0.26205602288246155
# 8700 0.4228213429450989
# 8800 0.34385713934898376
# 8900 0.42270708084106445
# 9000 0.3889751732349396
# 9100 0.20830827951431274
# 9200 0.30716824531555176
# 9300 0.2632165849208832
# 9400 0.20055124163627625
# 9500 0.19136178493499756
# 9600 0.15407569706439972
# 9700 0.36174771189689636
# 9800 0.32602038979530334
# 9900 0.17556026577949524
# 10000 0.31766948103904724
# Testing Set Cross Entropy Loss (Baseline Model): 1.0052971839904785
# Testing Set Accuracy (Baseline Model): 0.7491000294685364
# Training Set Cross Entropy Loss (Baseline Model): 0.20523808896541595
# Training Set Accuracy (Baseline Model): 0.9302200078964233
# TRAINING TIME: 7911.213276863098 seconds
# TEST TIME: 127.91747188568115 seconds

# %%
import torch
import torchvision
import cifar10
import torchvision.datasets as D
import numpy as np
import torch.nn as nn
from torch.nn.parameter import Parameter
import matplotlib
from matplotlib import pyplot as plt
import time
import Models
from Models import Conv2dBlock, CNNClassifier
import utils
from utils import load_data, safe_mkdir, get_paths

class RankConv2d(nn.Module):
    def __init__(self, rank, in_channels, out_channels, kernel_size = (3,3), padding = 'same'):
        super().__init__()
        assert(rank <= kernel_size[0] and rank <= kernel_size[1])
        self.in_c = in_channels
        self.out_c = out_channels
        self.rank = rank
        self.padding = padding
        
        W0 = torch.empty(self.out_c, self.in_c, kernel_size[0], kernel_size[1])
        nn.init.xavier_uniform_(W0)
        U, S, V = torch.linalg.svd(W0)
        
        self.left_W = Parameter(torch.sqrt(S[:,:,:rank]).unsqueeze(2) * U[:,:,:,:rank])
        self.right_W = Parameter(torch.sqrt(S[:,:,:rank]).unsqueeze(2) * V[:,:,:,:rank])
        self.left_W.requires_grad = True
        self.right_W.requires_grad = True
                
        self.bias = Parameter(torch.empty(self.out_c,))
        nn.init.zeros_(self.bias)
        self.bias.requires_grad = True
        
    def forward(self, x):
        return torch.nn.functional.conv2d(x, self.left_W @ torch.swapaxes(self.right_W, -1, -2), bias = self.bias, padding = self.padding)
    
class RankConv2dBlock(nn.Module):
    def __init__(self, channels, ranks, kernel_size = (3,3), padding = 'same', pool_size = (2,2), pool_stride = (2,2)):
        super().__init__()
        assert(len(channels) >= 2 and len(ranks) + 1 == len(channels))
        self.layers = []
        for i in range(1,len(channels)):
            prev_c, curr_c = channels[i-1], channels[i]
            self.layers.append(RankConv2d(ranks[i-1], in_channels = prev_c, out_channels = curr_c, kernel_size = kernel_size, padding = padding))
            self.layers.append(nn.ReLU())
        self.layers.append(nn.MaxPool2d(pool_size, pool_stride))
        self.model = nn.Sequential(*self.layers)
    def forward(self,x):
        return self.model(x)
        
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
X_TRAIN, X_TEST, Y_TRAIN, Y_TEST = load_data(DEVICE)

def run_exp_rank(DATA, DEVICE, kernels_size, ranks, seed = 42, ITERATIONS = 10000, BATCH_SIZE = 64, verbose = False, PRINT_EVERY = 100, OUT_CLASSES = 10):
    X_TRAIN, X_TEST, Y_TRAIN, Y_TEST = DATA
    parpath, folderpath = get_paths(kernels_size, ranks, seed)
    safe_mkdir(parpath)
    safe_mkdir(folderpath)
    
    np.random.seed(seed)
    torch.manual_seed(seed)
    layers = [RankConv2dBlock([3,32,32], [ranks,ranks], (kernels_size, kernels_size)), 
              RankConv2dBlock([32,64,64], [ranks,ranks], (kernels_size, kernels_size)), 
              RankConv2dBlock([64,128,128], [ranks,ranks], (kernels_size, kernels_size)), 
              nn.Flatten(), nn.Linear(2048,128), nn.ReLU(), nn.Linear(128,OUT_CLASSES)]
    MODEL = CNNClassifier(layers, 1e-3, nn.functional.cross_entropy).to(DEVICE)
    MODEL.train()

    print("DOING MODEL TRAINING, RANK: " + str(ranks) + ", KERNEL SIZE: " + str(kernels_size) + ", SEED: " + str(seed))
    print()
    
    losses = []
    train_start = time.time()

    for itr in range(ITERATIONS+1):
        idxs = np.random.randint(0,50000, size = (BATCH_SIZE,))

        X, Y = X_TRAIN[idxs], Y_TRAIN[idxs]
        
        loss = MODEL.backprop(X,Y)
        if itr%PRINT_EVERY == 0:
            if verbose:
                print(itr,loss)
        losses.append(loss)

    train_time = time.time() - train_start
    
    MODEL.eval()

    plt.clf()
    plt.plot(np.arange(len(losses)), np.array(losses))
    plt.title("Cross Entropy Loss over Training, KS " + str(kernels_size) + " RANK " + str(ranks) + " seed " + str(seed))
    plt.savefig(folderpath + "/loss_graph.png")
    plt.clf()

    test_start = time.time()
    loss = MODEL.compute_loss(X_TEST, Y_TEST)
    acc = MODEL.compute_accuracy(X_TEST, Y_TEST)
    test_time = time.time() - test_start

    print("Testing Set Cross Entropy Loss:", loss)
    print("Testing Set Accuracy:", acc)

    loss = MODEL.compute_loss(X_TRAIN, Y_TRAIN)
    acc = MODEL.compute_accuracy(X_TRAIN, Y_TRAIN)

    print("Training Set Cross Entropy Loss:", loss)
    print("Training Set Accuracy:", acc)

    print("TRAINING TIME:", train_time, "seconds")
    print("TEST TIME:",test_time, "seconds")
    
    np.savetxt(folderpath + "/losses.txt", np.array(losses))
    np.savetxt(folderpath + "/results_data.txt", np.array([loss, acc, train_time, test_time]))
    
    return losses, loss, acc, train_time, test_time

run_exp_rank
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# torch.Size([32, 3, 3, 1]) torch.Size([32, 3, 3, 1])
# torch.Size([32, 32, 3, 1]) torch.Size([32, 32, 3, 1])
# torch.Size([64, 32, 3, 1]) torch.Size([64, 32, 3, 1])
# torch.Size([64, 64, 3, 1]) torch.Size([64, 64, 3, 1])
# torch.Size([128, 64, 3, 1]) torch.Size([128, 64, 3, 1])
# torch.Size([128, 128, 3, 1]) torch.Size([128, 128, 3, 1])
# DOING BASELINE MODEL TRAINING
#
# 0 2.3118412494659424
# 100 1.8981837034225464
# 200 1.5126097202301025
# 300 1.4412870407104492
# 400 1.4528157711029053
# 500 1.5976529121398926
# 600 1.4637200832366943
# 700 1.1542879343032837
# 800 1.0365793704986572
# 900 1.3773852586746216
# 1000 1.0797959566116333
# 1100 1.1004434823989868
# 1200 1.1631405353546143
# 1300 0.96293044090271
# 1400 0.9334040880203247
# 1500 1.1362727880477905
# 1600 0.8782923817634583
# 1700 1.1469134092330933
# 1800 1.0904948711395264
# 1900 0.7256811261177063
# 2000 0.9824048280715942
# 2100 1.2150486707687378
# 2200 0.8639328479766846
# 2300 0.8103113174438477
# 2400 0.7624039649963379
# 2500 0.6582669019699097
# 2600 0.8802701830863953
# 2700 0.6461815237998962
# 2800 0.8614823222160339
# 2900 0.7144522666931152
# 3000 0.6811683177947998
# 3100 0.7607042193412781
# 3200 0.5263004899024963
# 3300 0.577175498008728
# 3400 0.3693782389163971
# 3500 0.5253919363021851
# 3600 0.7252280712127686
# 3700 0.7737972736358643
# 3800 0.5657135844230652
# 3900 0.5558987259864807
# 4000 0.5740023255348206
# 4100 0.5328565239906311
# 4200 0.5439625382423401
# 4300 0.5554381608963013
# 4400 0.4425203204154968
# 4500 0.6343047618865967
# 4600 0.47931215167045593
# 4700 0.2677904963493347
# 4800 0.5223226547241211
# 4900 0.5686697959899902
# 5000 0.3692812919616699
# 5100 0.5789648294448853
# 5200 0.35690510272979736
# 5300 0.4161633253097534
# 5400 0.26184627413749695
# 5500 0.45307818055152893
# 5600 0.26315197348594666
# 5700 0.5005639791488647
# 5800 0.4101038873195648
# 5900 0.4113531708717346
# 6000 0.3587067723274231
# 6100 0.4104495644569397
# 6200 0.22374357283115387
# 6300 0.23084436357021332
# 6400 0.48625266551971436
# 6500 0.47263863682746887
# 6600 0.6924435496330261
# 6700 0.20623773336410522
# 6800 0.43806448578834534
# 6900 0.21987441182136536
# 7000 0.2910245656967163
# 7100 0.3802646994590759
# 7200 0.1542600393295288
# 7300 0.1897326558828354
# 7400 0.33893102407455444
# 7500 0.31751760840415955
# 7600 0.2517467141151428
# 7700 0.575888991355896
# 7800 0.30002790689468384
# 7900 0.17608609795570374
# 8000 0.2521795630455017
# 8100 0.19892364740371704
# 8200 0.2002471387386322
# 8300 0.30650198459625244
# 8400 0.35348719358444214
# 8500 0.17955869436264038
# 8600 0.11507672071456909
# 8700 0.1719205379486084
# 8800 0.15582157671451569
# 8900 0.5310555696487427
# 9000 0.20495860278606415
# 9100 0.1195368692278862
# 9200 0.25718584656715393
# 9300 0.1288248598575592
# 9400 0.36269938945770264
# 9500 0.12556250393390656
# 9600 0.17642779648303986
# 9700 0.18167917430400848
# 9800 0.18173012137413025
# 9900 0.14119325578212738
# 10000 0.06684201955795288
# Testing Set Cross Entropy Loss (Baseline Model): 1.1271965503692627
# Testing Set Accuracy (Baseline Model): 0.7523999810218811
# Training Set Cross Entropy Loss (Baseline Model): 0.12499075382947922
# Training Set Accuracy (Baseline Model): 0.9593999981880188
# TRAINING TIME: 5071.232131719589 seconds
# TEST TIME: 68.72871398925781 seconds

# %%
import torch
import torchvision
import cifar10
import torchvision.datasets as D
import numpy as np
import torch.nn as nn
import matplotlib
from matplotlib import pyplot as plt
import time
import Models
from Models import Conv2dBlock, CNNClassifier
import utils
from utils import load_data

np.random.seed(42)
torch.manual_seed(42)

class RankConv2d(nn.Module):
    def __init__(self, rank, in_channels, out_channels, kernel_size = (3,3), padding = 'same'):
        super().__init__()
        assert(rank <= kernel_size[0] and rank <= kernel_size[1])
        self.in_c = in_channels
        self.out_c = out_channels
        self.rank = rank
        self.padding = padding
        
        self.left_W = torch.empty(out_c, in_c, kernel_size[0], rank)
        self.right_W = torch.empty(out_c, in_c, rank, kernel_size[1])
        nn.init.xavier_uniform_(self.left_W, gain=nn.init.calculate_gain('relu'))
        nn.init.xavier_uniform_(self.right_W, gain=nn.init.calculate_gain('relu'))
        self.left_W.requires_grad = True
        self.right_W.requires_grad = True
        
        self.bias = torch.empty(out_c,)
        nn.init.zeros_(self.bias)
        self.bias.requires_grad = True
        
    def forward(self, x):
        return torch.nn.functional(x, self.self.left_W @ self.right_W, bias = self.bias, padding = self.padding)
    
class RankConv2dBlock(nn.Module):
    def __init__(self, channels, ranks, kernel_size = (3,3), padding = 'same', pool_size = (2,2), pool_stride = (2,2)):
        super().__init__()
        assert(len(channels) >= 2 and len(ranks) + 1 == len(channels))
        self.layers = []
        for i in range(1,len(channels)):
            prev_c, curr_c = channels[i-1], channels[i]
            self.layers.append(RankConv2d(ranks[i-1], in_channels = prev_c, out_channels = curr_c, kernel_size = kernel_size, padding = padding))
            self.layers.append(nn.ReLU())
        self.layers.append(nn.MaxPool2d(pool_size, pool_stride))
        self.model = nn.Sequential(*self.layers)
    def forward(self,x):
        return self.model(x)
        

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

X_TRAIN, X_TEST, Y_TRAIN, Y_TEST = load_data(DEVICE)

ITERATIONS = 10000
BATCH_SIZE = 64
PRINT_EVERY = 100
OUT_CLASSES = 10
        

layers = [Conv2dBlock([3,32,32], [1,1]), Conv2dBlock([32,64,64], [1,1]), Conv2dBlock([64,128,128], [1,1]), 
          nn.Flatten(), nn.Linear(2048,128), nn.ReLU(), nn.Linear(128,OUT_CLASSES)]
        
MODEL = CNNClassifier(layers, 1e-3, nn.functional.cross_entropy).to(DEVICE)

print("DOING BASELINE MODEL TRAINING")
print()

losses = []
train_start = time.time()

for itr in range(ITERATIONS+1):
    idxs = np.random.randint(0,50000, size = (BATCH_SIZE,))
        
    X, Y = X_TRAIN[idxs], Y_TRAIN[idxs]
    
    loss = MODEL.backprop(X,Y)
    if itr%PRINT_EVERY == 0:
        print(itr,loss)
    losses.append(loss)

train_time = time.time() - train_start
        
plt.clf()
plt.plot(np.arange(len(losses)), np.array(losses))
plt.title("Cross Entropy Loss over Training (Baseline Model)")
plt.show()
plt.clf()

test_start = time.time()
loss = MODEL.compute_loss(X_TEST, Y_TEST)
acc = MODEL.compute_accuracy(X_TEST, Y_TEST)
test_time = time.time() - test_start

print("Testing Set Cross Entropy Loss (Baseline Model):", loss)
print("Testing Set Accuracy (Baseline Model):", acc)

loss = MODEL.compute_loss(X_TRAIN, Y_TRAIN)
acc = MODEL.compute_accuracy(X_TRAIN, Y_TRAIN)

print("Training Set Cross Entropy Loss (Baseline Model):", loss)
print("Training Set Accuracy (Baseline Model):", acc)

print("TRAINING TIME:", train_time, "seconds")
print("TEST TIME:",test_time, "seconds")

# %%
tt = torch.randn(1, 3)
x = torch.as_strided(tt, (10, 10), (1,1))
# Out:
# ------------------------------------
# RuntimeErrorTraceback (most recent call last)
# Cell In[48], line 2
#       1 tt = torch.randn(1, 3)
# ----> 2 x = torch.as_strided(tt, (10, 10), (1,1))
#
# RuntimeError: setStorage: sizes [10, 10], strides [1, 1], storage offset 0, and itemsize 4 requiring a storage size of 76 are out of bounds for storage of size 12
